# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv(r"C:\Users\DAMANPREET\Desktop\Customer-churn-platform\data\WA_Fn-UseC_-Telco-Customer-Churn.csv")

df.head()
# Out:
#   Cell In[6], line 1
#     df = pd.read_csv("C:\Users\DAMANPREET\Desktop\Customer-churn-platform\data\WA_Fn-UseC_-Telco-Customer-Churn.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
